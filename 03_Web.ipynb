# %% [markdown]
# # 인터넷 자동화
# - 인터넷 자동화(50%), 엑셀 자동화(10%), 기타 자동화(15%)

# %%
# 1) 인터넷 브라우저열기 (AI 잘모름)
# 2) 원하는 사이트 접속하기
# 3) 원하는 웹 요소 찾기 (AI 잘모름)
# 4) 웹 요소에 데이터 입력하기
# 5) 웹 요소를 클릭하기
# 6) 웹 요소의 텍스트 / 속성값 출력하기
# 7) 기다리기

# %% [markdown]
# ## 드라이브 자동 설정

# %%
# !pip install selenium                    
# !pip install selenium==4.28.1

# %%
from selenium import webdriver

# %%
# 1) 웹 브라우저 열기 
driver=webdriver.Chrome()             # 크롬 브라우저 실행

# %%
# 2) 원하는 사이트 접속 하기 
driver.get("https://www.naver.com")   # 네이버 접속

# %% [markdown]
# ## 드라이스 수동 설정

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# 1) 웹 브라우저 열기 
service=Service("C:/chromedriver.exe")
driver=webdriver.Chrome(service=service)

# %%
# 2) 원하는 사이트 접속 하기 
driver.get("https://www.naver.com")

# %% [markdown]
# # 네이버 사이트 접속
# - [프롬프트]
#      - Python과 Selenium을 사용해 네이버에서 검색어를 입력하는 코드를 작성하고 싶어. 아래 조건에 맞게 코드를 만들어줘.
#         -  네이버 메인 페이지의 초록색 검색창 웹 요소 ID는 "query"이며, 이를 green_box_ele 변수에 할당해줘.
#         -  green_box_ele 요소에 "에어컨"이라는 검색어를 입력하는 코드를 만들어줘.

# %%
# - Python과 Selenium을 사용해 네이버에서 검색어를 입력하는 코드를 작성하고 싶어. 아래 조건에 맞게 코드를 만들어줘. 
#     -  네이버 메인 페이지의 초록색 검색창 웹 요소 ID는 "query"이며, 이를 green_box_ele 변수에 할당해줘. 
#     -  green_box_ele 요소에 "에어컨"이라는 검색어를 입력하는 코드를 만들어줘.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# 1) 웹 브라우저 열기 
# 크롬 브라우저 실행 
driver = webdriver.Chrome()

# 2) 원하는 사이트 접속 하기 
# 네이버 접속 
driver.get("https://www.naver.com")

# 3) 원하는 웹 요소 찾기
# 초록색 검색창(ID: query)을 green_box_ele 변수에 저장
green_box_ele = driver.find_element(By.ID, "query")

# 4) 웹 요소에 데이터 입력
# "에어컨" 검색어 입력
green_box_ele.send_keys("에어컨")

# %% [markdown]
# - [프롬프트]
#     - 웹 요소의 클래스(CLASS) 이름은 "ai_effect_symbol"이며, 이를 ai_s_else 변수에 할당해줘.
#     - ai_s_else 변수에 할당된 버튼 요소를 클릭하는 코드를 만들어줘

# %%
# - 웹 요소의 클래스(CLASS) 이름은 "ai_effect_symbol"이며, 이를 ai_s_else 변수에 할당해줘.
# - ai_s_else 변수에 할당된 버튼 요소를 클릭하는 코드를 만들어줘

# %%
# 5-1) 웹 요소를 클릭하기
# 클래스 이름이 "ai_effect_symbol"인 요소를 ai_s_else 변수에 할당
ai_s_else = driver.find_element(By.CLASS_NAME, "ai_effect_symbol")

# 버튼 클릭
ai_s_else.click()

# %% [markdown]
# - [프롬프트]
#     - 웹 요소의 클래스(CLASS) 이름 "wxxES_QvNoYHFNCZ" 인 모든 웹 요소 중에서 "카페"라는 텍스트를 보유한 웹 요소를 클릭하는 코드 만들어줘

# %%
# - 웹 요소의 클래스(CLASS) 이름 "wxxES_QvNoYHFNCZ" 인 모든 웹 요소 중에서 "카페"라는 텍스트를 보유한 웹 요소를 클릭하는 코드 만들어줘

# %%
# 5-2) 웹 요소를 클릭하기
# 클래스명이 "wxxES_QvNoYHFNCZ"인 모든 요소 찾기
elements = driver.find_elements(By.CLASS_NAME, "wxxES_QvNoYHFNCZ")

# 텍스트가 "카페"인 요소 클릭
for element in elements:
    if element.text.strip() == "카페":
        element.click()
        print("카페 메뉴를 클릭했습니다.")
        break
# Out:
# 카페 메뉴를 클릭했습니다.

# %% [markdown]
# - [프롬프트]
#     - 웹 요소의 클래스(CLASS) 이름이 'title_link'인 웹요소모두를 가져와서 반복문을
#     - 통해 각각의 웹요소에 포함된 텍스트와 URL(href속성값)을 출력해줘

# %%
# - 웹 요소의 클래스(CLASS) 이름이 'title_link'인 웹요소모두를 가져와서 반복문을 통해 각각의 웹요소에 포함된 텍스트와 URL(href속성값)을 출력해줘

# %%
# 6) 웹 요소의 텍스트 / 속성값 출력하기
# 클래스명이 'title_link'인 모든 요소 가져오기
title_links = driver.find_elements(By.CLASS_NAME, "title_link")

# 각 요소의 텍스트와 URL 출력
for idx, element in enumerate(title_links, start=1):
    title = element.text.strip()
    url = element.get_attribute("href")

    print(f"[{idx}]")
    print("제목 :", title)
    print("URL  :", url)
    print("-" * 50)
# Out:
# [1]
# 제목 : 에어컨렌탈 지원 많은곳! 당일지급 전국접수 빠른설치
# URL  : https://ader.naver.com/v1/J_FTGEGv0DtXDB4O7rCJZg6dx1OWiKe3HNjG3nJqEaFM64BDfEQcyqi9c53CnKcxsAM0BCpb4OnTU61Daq3amJ-2Q6EQVOMEcWVXvKfB-zARlkGI_hx-FaUZGeVeWgNJHj7GersiO1O6fYAeWcTwCETuAwRhUKLK3sfNt8A1RJlcZMOMvsGOD_Rh9X-WP9Ld3WXlNgHL9FiiYwPcq8S07h1SI8CUa0uT9YQ-_OqRLGRsEoodZ28g7kJ9GXCzpOinHAo_LVBPH5mMl4LVuTMlcBYv3y5MqdX2X8zk7B72iUU=?c=naver.search.pc.tab.cafe.pwc&t=0
# --------------------------------------------------
# [2]
# 제목 : 시스템 에어컨은 송풍 시 원래 냄새나나요?
# URL  : https://cafe.naver.com/skybluezw4rh/14763296?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InNreWJsdWV6dzRyaCIsImFydGljbGVJZCI6MTQ3NjMyOTYsImlzc3VlZEF0IjoxNzg1NzIwMzE4NDAzfQ.hTkpS0cbjUQhumR_zDzI_gzUe5FQOK5dQ-PAjT58voU&q=%ec%97%90%ec%96%b4%ec%bb%a8&tc=naver_search
# --------------------------------------------------
# [3]
# 제목 : 시스템 에어컨 냉기가 약해요
# ...

# %%
# 7) 기다리기
import time
st = 3
print(1)

time.sleep(st)
print(2)
# Out:
# 1
# 2

# %% [markdown]
# - 1번 ~ 7번까지 합치기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

st = 3
time.sleep(st)

# 1) 웹 브라우저 열기 
# 크롬 브라우저 실행 
driver = webdriver.Chrome()

# 2) 원하는 사이트 접속 하기 
# 네이버 접속 
driver.get("https://www.naver.com")

# 3) 원하는 웹 요소 찾기
# 초록색 검색창(ID: query)을 green_box_ele 변수에 저장
green_box_ele = driver.find_element(By.ID, "query")

# 4) 웹 요소에 데이터 입력
# "에어컨" 검색어 입력
green_box_ele.send_keys("에어컨")

# 5-1) 웹 요소를 클릭하기
# 클래스 이름이 "ai_effect_symbol"인 요소를 ai_S_ELSE 변수에 할당
ai_s_else = driver.find_element(By.CLASS_NAME, "ai_effect_symbol")

# 버튼 클릭
ai_s_else.click()

# 5-2) 웹 요소를 클릭하기
# 클래스명이 "wxxES_QvNoYHFNCZ"인 모든 요소 찾기
elements = driver.find_elements(By.CLASS_NAME, "wxxES_QvNoYHFNCZ")

# 텍스트가 "카페"인 요소 클릭
for element in elements:
    if element.text.strip() == "카페":
        element.click()
        print("카페 메뉴를 클릭했습니다.")
        break

# 6) 웹 요소의 텍스트 / 속성값 출력하기
# 클래스명이 'title_link'인 모든 요소 가져오기
title_links = driver.find_elements(By.CLASS_NAME, "title_link")

# 각 요소의 텍스트와 URL 출력
for idx, element in enumerate(title_links, start=1):
    title = element.text.strip()
    url = element.get_attribute("href")

    print(f"[{idx}]")
    print("제목 :", title)
    print("URL  :", url)
    print("-" * 50)
# Out:
# 카페 메뉴를 클릭했습니다.
# [1]
# 제목 : 에어컨렌탈 지원 많은곳! 당일지급 전국접수 빠른설치
# URL  : https://ader.naver.com/v1/fX3_ptVM6GM8IzuhIMASdkSNqWdBWPPpA6nY0uWwk7-NATJQtmNPRXM2mN2zdpuRt2yOX-bbIfnVPTw2LXQ-86KFfqD_t80mOfkCEM3OTWEtI1jY5Ik8jGg9eIRekztlyQ5ZHqI4j-_9ylq4vqtsSgf9iqTRXUH_B4C-_5GG2cQkHeE2nN8I8ru2vt4ID3BFf7hr4FPofrySIT8JttnlBxkhSTTKzmzXW1E96LHKNxgI6kQghFExTZtt-noOOIhVD2F6dLRhkmd81B8wRxjxKPou8mzJHg45TPthPRoyreY=?c=naver.search.pc.tab.cafe.pwc&t=0
# --------------------------------------------------
# [2]
# 제목 : 시스템 에어컨 4대 가격이 왜 다 다를까요~?
# URL  : https://cafe.naver.com/overseer/1714638?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Im92ZXJzZWVyIiwiYXJ0aWNsZUlkIjoxNzE0NjM4LCJpc3N1ZWRBdCI6MTc4NTY2MTY4MDg0OH0.oj8GYccKNH7gbkBbWoDHTPp5vluVt6U-wKQYTkri7Dw&q=%ec%97%90%ec%96%b4%ec%bb%a8&tc=naver_search
# --------------------------------------------------
# [3]
# 제목 : 시스템에어컨 쓰시는분 만족하시나요??
# ...

# %% [markdown]
# # 질문만으로 에러없는 Selenium 코드 만들기

# %% [markdown]
# - New Chat : [프롬프트]
#     - 아래의 코드를 기억해줘 >> 위 완성본 던지기
#     - 위에서 내가 제공해준 코드를 기반으로 아래의 기능을 추가하여 발전시켜줘
#         - "에어컨" 단어 뿐만 아니라 임의의 5개 여름 전자제품 단어검색으로 확장
#         - "반복동작 루틴은 네이버접속 ~ 게시글출력까지

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# 대기시간
st = 3

# 검색할 여름 전자제품
keywords = [
    "에어컨",
    "선풍기",
    "제습기",
    "냉풍기",
    "서큘레이터"
]

# ==================================================
# 키워드별 반복
# ==================================================
for keyword in keywords:

    print("=" * 70)
    print(f"검색 키워드 : {keyword}")
    print("=" * 70)

    # 1) 웹 브라우저 열기
    driver = webdriver.Chrome()

    # 2) 네이버 접속
    driver.get("https://www.naver.com")
    time.sleep(st)

    # 3) 검색창 찾기
    green_box_ele = driver.find_element(By.ID, "query")

    # 4) 검색어 입력
    green_box_ele.send_keys(keyword)

    # 5) 검색 버튼 클릭
    ai_s_else = driver.find_element(By.CLASS_NAME, "ai_effect_symbol")
    ai_s_else.click()
    time.sleep(st)

    # 6) 카페 메뉴 클릭
    elements = driver.find_elements(By.CLASS_NAME, "wxxES_QvNoYHFNCZ")

    for element in elements:
        if element.text.strip() == "카페":
            element.click()
            print("카페 메뉴를 클릭했습니다.")
            break

    time.sleep(st)

    # 7) 게시글 제목 및 URL 출력
    title_links = driver.find_elements(By.CLASS_NAME, "title_link")

    for idx, element in enumerate(title_links, start=1):

        title = element.text.strip()
        url = element.get_attribute("href")

        print(f"[{idx}]")
        print("제목 :", title)
        print("URL  :", url)
        print("-" * 50)

    # 브라우저 종료
    driver.quit()

    print(f"{keyword} 검색 완료\n")
# Out:
# ...
# 검색 키워드 : 에어컨
# ...
# 카페 메뉴를 클릭했습니다.
# [1]
# 제목 : 에어컨렌탈 지원 많은곳! 당일지급 전국접수 빠른설치
# URL  : https://ader.naver.com/v1/rLW2q-znKOIkr5pqq4bx6VOckYP4uOAD6fiis2u7lvyLTpa8n-U-seEZl5p3rFdQRfoWfINrIIGmD1qRr3ul5XhzshLnpl73w2YPNZVk8mJvqhrXW22K-EBnp-lCsdPFWywnj8zjQDd-gcE3gwDBEQbq-JoPmLTRx_ZJNpDo5Wis_3D1tPPmoKefI9doXEvb6TRdIYnInOzhIJfqGRHn6liiHtV9yUI7jVwdjlppMF-GYWwvnHVC8pJS_Ywrj7oZ?c=naver.search.pc.tab.cafe.pwc&t=0
# --------------------------------------------------
# [2]
# 제목 : 시스템 에어컨 4대 가격이 왜 다 다를까요~?
# URL  : https://cafe.naver.com/overseer/1714638?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Im92ZXJzZWVyIiwiYXJ0aWNsZUlkIjoxNzE0NjM4LCJpc3N1ZWRBdCI6MTc4NTcyMDM3NjQwMX0.84xa_oZBzbsRTM9OeBKfKWwJzxJUnC2f-tB5jhkQfjo&q=%ec%97%90%ec%96%b4%ec%bb%a8&tc=naver_search
# --------------------------------------------------
# [3]
# 제목 : 시스템에어컨 쓰시는분 만족하시나요??
# ...

# %% [markdown]
# ## 엑셀로 저장하기
# - [프롬프트]
#     - 위의 코드를 기반으로 아래의 기능을 추가하여 발전시켜줘
#         - 출력되는 내용을 기반으로 엑셀로 제작하기
#         - 엑셀의 구조는 ["키워드", 게시글제목", "URL"]
#         - 엑셀저장경로 D:\Edu\Machine Learning\workspace\20.업무자동화\결과\웹
#         - 엑셀파일명 "naver_cafe_elect01.xlsx"

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import os


# 대기시간
st = 3


# 검색할 여름 전자제품
keywords = [
    "에어컨",
    "선풍기",
    "제습기",
    "냉풍기",
    "서큘레이터"
]


# 엑셀 저장 리스트
result_list = []


# ==================================================
# 키워드 반복 검색
# ==================================================
for keyword in keywords:

    print("=" * 70)
    print(f"검색 키워드 : {keyword}")
    print("=" * 70)


    # 1) 크롬 실행
    driver = webdriver.Chrome()


    # 2) 네이버 접속
    driver.get("https://www.naver.com")
    time.sleep(st)


    # 3) 검색창 찾기
    green_box_ele = driver.find_element(
        By.ID,
        "query"
    )


    # 4) 검색어 입력
    green_box_ele.send_keys(keyword)


    # 5) 검색 버튼 클릭
    ai_s_else = driver.find_element(
        By.CLASS_NAME,
        "ai_effect_symbol"
    )

    ai_s_else.click()

    time.sleep(st)


    # 6) 카페 메뉴 클릭
    elements = driver.find_elements(
        By.CLASS_NAME,
        "wxxES_QvNoYHFNCZ"
    )


    for element in elements:

        if element.text.strip() == "카페":

            element.click()

            print("카페 메뉴 클릭 완료")

            break


    time.sleep(st)


    # 7) 게시글 제목 / URL 수집
    title_links = driver.find_elements(
        By.CLASS_NAME,
        "title_link"
    )


    for idx, element in enumerate(title_links, start=1):

        title = element.text.strip()

        url = element.get_attribute("href")


        print(f"[{idx}]")
        print("제목 :", title)
        print("URL :", url)
        print("-"*50)


        # ===============================
        # Excel 저장용 데이터 추가
        # ===============================
        result_list.append(
            {
                "키워드": keyword,
                "게시글제목": title,
                "URL": url
            }
        )


    # 브라우저 종료
    driver.quit()


    print(f"{keyword} 검색 완료\n")



# ==================================================
# DataFrame 생성
# ==================================================

df = pd.DataFrame(result_list)


print("\n수집 데이터 확인")
print(df)



# ==================================================
# Excel 저장
# ==================================================

save_path = r"D:\Edu\Machine Learning\workspace\20.업무자동화\결과\웹"


# 폴더 없으면 생성
if not os.path.exists(save_path):
    os.makedirs(save_path)


file_name = "naver_cafe_elect01.xlsx"


full_path = os.path.join(
    save_path,
    file_name
)


# Excel 저장
df.to_excel(
    full_path,
    index=False
)


print("="*70)
print("Excel 저장 완료")
print(full_path)
print("="*70)
# Out:
# ...
# 검색 키워드 : 에어컨
# ...
# 카페 메뉴 클릭 완료
# [1]
# 제목 : 에어컨렌탈 지원 많은곳! 당일지급 전국접수 빠른설치
# URL : https://ader.naver.com/v1/2aBzPzuZnfVeLYj_1_9aB-sW2wjSev8cZ3CWKxreLI6ZoZaYW-sjqyunlr0kECYYRzhGf2nsI6T1zbHum-dsrulxo7CvRwMZtIfs0SI6qXXoXBGgM7RxFEMDIlfN5p8bgFkGeVtcpsUKRPyP87wz3l0mfK85rIdiE9TxWWaupVtcBCg7xDIKQ3XkOc0I5dlEP_F3hQzsw4k2-5XFZ_dWqO5TJSnq8MHMwHT2OGcZ9qh2nw1PlhqFLXq0ycrnX_ev9iVftgODw4fJp9vNvLQeWIWJZnFiwRp2nnFkEGNSMKs=?c=naver.search.pc.tab.cafe.pwc&t=0
# --------------------------------------------------
# [2]
# 제목 : 시스템 에어컨은 송풍 시 원래 냄새나나요?
# URL : https://cafe.naver.com/skybluezw4rh/14763296?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6InNreWJsdWV6dzRyaCIsImFydGljbGVJZCI6MTQ3NjMyOTYsImlzc3VlZEF0IjoxNzg1NzIwODM5MTAwfQ.2GVgqC7UsYSgJvgYsCL_NcTDJCOkqrysOzg4QzPNlG0&q=%ec%97%90%ec%96%b4%ec%bb%a8&tc=naver_search
# --------------------------------------------------
# [3]
# 제목 : 시스템 에어컨 냉기가 약해요
# ...

# %% [markdown]
# ## 병렬처리
# - [프롬프트]
#     - 위의 코드를 기반으로 아래의 기능을 추가하여 발전시켜줘
#         - 순차적으로 5개를 검색하지말고, 병렬처리해서 한꺼번에 동작해서 코드 속도를 높여줘

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import os

from concurrent.futures import ThreadPoolExecutor, as_completed


# 대기시간
st = 3


# 검색 키워드
keywords = [
    "에어컨",
    "선풍기",
    "제습기",
    "냉풍기",
    "서큘레이터"
]



# ==========================================
# 하나의 키워드 검색 함수
# ==========================================

def naver_cafe_search(keyword):

    result = []


    print("="*60)
    print(f"{keyword} 검색 시작")
    print("="*60)



    # 크롬 실행
    driver = webdriver.Chrome()


    try:

        # 네이버 접속
        driver.get("https://www.naver.com")
        time.sleep(st)



        # 검색창
        green_box_ele = driver.find_element(
            By.ID,
            "query"
        )


        # 검색어 입력
        green_box_ele.send_keys(keyword)



        # 검색 버튼 클릭
        ai_s_else = driver.find_element(
            By.CLASS_NAME,
            "ai_effect_symbol"
        )

        ai_s_else.click()

        time.sleep(st)



        # 카페 메뉴 클릭
        elements = driver.find_elements(
            By.CLASS_NAME,
            "wxxES_QvNoYHFNCZ"
        )


        for element in elements:

            if element.text.strip() == "카페":

                element.click()

                print(
                    f"{keyword} 카페 클릭 완료"
                )

                break


        time.sleep(st)



        # 게시글 가져오기
        title_links = driver.find_elements(
            By.CLASS_NAME,
            "title_link"
        )



        for element in title_links:


            title = element.text.strip()

            url = element.get_attribute(
                "href"
            )


            print(
                keyword,
                title
            )


            result.append(
                {
                    "키워드": keyword,
                    "게시글제목": title,
                    "URL": url
                }
            )


    except Exception as e:

        print(
            keyword,
            "오류 발생 :",
            e
        )


    finally:

        # 브라우저 종료
        driver.quit()



    print(
        f"{keyword} 검색 완료"
    )


    return result





# ==========================================
# 병렬 실행
# ==========================================


total_result = []



# 동시에 실행할 브라우저 개수
with ThreadPoolExecutor(max_workers=5) as executor:


    futures = []


    for keyword in keywords:

        futures.append(
            executor.submit(
                naver_cafe_search,
                keyword
            )
        )



    # 결과 수집
    for future in as_completed(futures):

        data = future.result()

        total_result.extend(data)




# ==========================================
# Excel 저장
# ==========================================


df = pd.DataFrame(
    total_result
)



save_path = r"D:\Edu\Machine Learning\workspace\20.업무자동화\결과\웹"



if not os.path.exists(save_path):

    os.makedirs(save_path)



file_path = os.path.join(
    save_path,
    "naver_cafe_elect02.xlsx"
)



df.to_excel(
    file_path,
    index=False
)



print("="*70)
print("Excel 저장 완료")
print(file_path)
print("="*70)



print(df)
# Out:
# ...
# 선풍기 검색 시작
# ...
#
# 에어컨 검색 시작
# ...
# 제습기 검색 시작
# ...
# 냉풍기 검색 시작
# ...
# 서큘레이터 검색 시작
# ...
# 에어컨 카페 클릭 완료
# 에어컨 에어컨렌탈 지원 많은곳! 당일지급 전국접수 빠른설치
# 에어컨 시스템 에어컨 4대 가격이 왜 다 다를까요~?
# 제습기 카페 클릭 완료
# 에어컨 시스템에어컨 쓰시는분 만족하시나요??
# 에어컨 시스템 에어컨!
# 선풍기 카페 클릭 완료
# 에어컨 캠핑용 에어컨 가동시 이너텐트안 시원한가요?
# 제습기 제습기 고를때 이거 꼭 확인하셔야해요
# 에어컨 시스템에어컨 이용하시는 맘님들.. 질문요
# 제습기 제습기렌탈 가전렌탈 지원 많은곳! 당일지급 전국접수
# 에어컨 인버터형 에어컨 전기요금 어때요?
# 제습기 제습기 하루종일 켜시나요?
# 선풍기 2026 선풍기 TOP3 순위공개! 가격,성능 비교
# 에어컨 에어컨 24시간가동 몇일동안해보셨어요?
# 제습기 제습기 살까요
# 선풍기 하이마트 9900원 선풍기 구매후기
# 제습기 제습기 이용시 창문은?
# 에어컨 시스템에어컨 lg 삼성 고민입니다
# 선풍기 집 & 캠핑 같이 사용할수있는 선풍기 추천 부탁드립니다.
# 에어컨 분양 아파트 시스템 에어컨 옵션요
# 제습기 엘지 제습기 쓰시는분들 와주세여
# 선풍기 선풍기 추천좀 부탁드립니다 ㅠ ㅠ
# 제습기 제습기 사용하시는 분 계신가요
# 에어컨 시스템 에어컨 견적을 인테리어업체에서 받았는데 적당한지 봐주세요!ㅎ
# 서큘레이터 카페 클릭 완료선풍기 하이마트 선풍기 샀어요!
#
# 에어컨 다들 에어컨 온도 몇도로 설정하고 다니세요?
# 제습기 에어컨을 풀가동한다면 제습기는 필요없는거 맞나요.???
# 에어컨 에어컨 연속 며칠까지 켜보셨나요? 저는 이틀째
# 선풍기 손선풍기 잘 쓰시나요?
# 제습기 제습기 용량 궁금해요.
# 에어컨 시스템 에어컨 쓰시는분들께 질문이요~
# 선풍기 하이마트 선풍기 9900원에 구입할수있어요~(조건있음)
# 제습기 1층 제습기 효과
# 에어컨선풍기 휴대용 선풍기 추천해주세요.
# ...

# %% [markdown]
# # 메일 자동화
# - [프롬프트]
#     - 지메일 자동으로 전송하는 코드 작성해줘
#     - [보내는 사람] : jwaminhye@gmail.com
#     - [받는사람] : jwaminhye@gmail.com
#     - [파일경로] : D:\Edu\Machine Learning\workspace\20.업무자동화\결과\웹 엑셀파일명 "naver_cafe_elect01.xlsx"
#     - [제목] : 여름 냉방 상품 5개 추천
#     - [내용] : 네이버에서 5개의 냉방 상품을 검색후, 카페 게시글의 갯수를 정리해서 보냅니다.
# - 비밀번호 만든법 : PPT 참조) dywc dtak koyv fioz

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
import os


# ===============================
# Gmail 정보
# ===============================

SENDER = "jwaminhye@gmail.com"
RECEIVER = "jwaminhye@gmail.com"

# Gmail 앱 비밀번호 입력 (16자리)
APP_PASSWORD = "dywc dtak koyv fioz"


# ===============================
# 메일 정보
# ===============================

SUBJECT = "여름 냉방 상품 5개 추천"

BODY = """
네이버에서 5개의 냉방 상품을 검색후,
카페 게시글의 갯수를 정리해서 보냅니다.
"""


# ===============================
# 첨부파일 경로
# ===============================

FILE_PATH = r"D:\Edu\Machine Learning\workspace\20.업무자동화\결과\웹\naver_cafe_elect01.xlsx"


# ===============================
# 이메일 생성
# ===============================

msg = MIMEMultipart()

msg["From"] = SENDER
msg["To"] = RECEIVER
msg["Subject"] = SUBJECT


# 본문 추가
msg.attach(
    MIMEText(BODY, "plain", "utf-8")
)


# ===============================
# 파일 첨부
# ===============================

if os.path.exists(FILE_PATH):

    filename = os.path.basename(FILE_PATH)

    with open(FILE_PATH, "rb") as attachment:
        part = MIMEBase(
            "application",
            "octet-stream"
        )
        part.set_payload(attachment.read())

    encoders.encode_base64(part)

    part.add_header(
        "Content-Disposition",
        f"attachment; filename={filename}"
    )

    msg.attach(part)

else:
    print("파일을 찾을 수 없습니다.")
    raise FileNotFoundError(FILE_PATH)


# ===============================
# Gmail SMTP 전송
# ===============================

try:

    server = smtplib.SMTP(
        "smtp.gmail.com",
        587
    )

    server.starttls()

    server.login(
        SENDER,
        APP_PASSWORD
    )

    server.sendmail(
        SENDER,
        RECEIVER,
        msg.as_string()
    )

    server.quit()

    print("메일 전송 완료!")

except Exception as e:
    print("메일 전송 실패:", e)
# Out:
# 메일 전송 완료!

# %% [markdown]
# - [프롬프트]
#     - 지메일 자동으로 전송하는 코드 작성해줘
#     - [보내는 사람] : jwaminhye@gmail.com
#     - [받는사람] : D:\Edu\Machine Learning\workspace\20.업무자동화\데이터 엑셀파일명 "메일전송.xlsx" 시트의 데이터 A2 ~ A7
#     - [파일경로] : D:\Edu\Machine Learning\workspace\20.업무자동화\결과\웹\엑셀파일명 "naver_cafe_elect01.xlsx"
#     - [제목] : 여름 냉방 상품 5개 추천
#     - [내용] : 네이버에서 5개의 냉방 상품을 검색후, 카페 게시글의 갯수를 정리해서 보냅니다.
# - 비밀번호 만든법 : PPT 참조) dywc dtak koyv fioz

# %%
import smtplib
import pandas as pd
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders


# ==========================================
# 1. 기본 설정
# ==========================================

# 보내는 사람
sender_email = "jwaminhye@gmail.com"

# Gmail 앱 비밀번호
# ※ Google 계정에서 생성한 16자리 앱 비밀번호 입력
app_password = "dywc dtak koyv fioz"


# 이메일 주소가 들어있는 Excel 파일
email_excel = r"D:\Edu\Machine Learning\workspace\20.업무자동화\데이터\메일전송.xlsx"

# 첨부할 Excel 파일
attachment_file = (
    r"D:\Edu\Machine Learning\workspace\20.업무자동화"
    r"\결과\웹\naver_cafe_elect01.xlsx"
)


# ==========================================
# 2. 메일전송.xlsx에서 A2~A7 이메일 가져오기
# ==========================================

df = pd.read_excel(
    email_excel,
    header=None
)

# A열의 2행~7행 → Python에서는 1~6번 인덱스
recipient_emails = df.iloc[1:7, 0].dropna().tolist()

print("받는 사람:")
for email in recipient_emails:
    print(email)


# ==========================================
# 3. 메일 내용
# ==========================================

subject = "여름 냉방 상품 5개 추천"

body = """안녕하세요.

네이버에서 5개의 냉방 상품을 검색후,
카페 게시글의 갯수를 정리해서 보냅니다.

첨부파일을 확인해 주세요.

감사합니다.
"""


# ==========================================
# 4. Gmail SMTP 서버 연결
# ==========================================

smtp_server = "smtp.gmail.com"
smtp_port = 587

server = smtplib.SMTP(smtp_server, smtp_port)

# TLS 보안 연결
server.starttls()

# Gmail 로그인
server.login(sender_email, app_password)


# ==========================================
# 5. A2~A7 모든 사람에게 메일 전송
# ==========================================

for recipient_email in recipient_emails:

    # 메일 생성
    msg = MIMEMultipart()

    # 보내는 사람
    msg["From"] = sender_email

    # 받는 사람
    msg["To"] = recipient_email

    # 제목
    msg["Subject"] = subject

    # 본문
    msg.attach(MIMEText(body, "plain", "utf-8"))


    # ======================================
    # 첨부파일 추가
    # ======================================

    with open(attachment_file, "rb") as attachment:

        part = MIMEBase("application", "octet-stream")

        part.set_payload(attachment.read())

    encoders.encode_base64(part)

    part.add_header(
        "Content-Disposition",
        f'attachment; filename="naver_cafe_elect01.xlsx"'
    )

    msg.attach(part)


    # ======================================
    # 메일 전송
    # ======================================

    server.sendmail(
        sender_email,
        recipient_email,
        msg.as_string()
    )

    print(f"메일 전송 완료 : {recipient_email}")


# ==========================================
# 6. SMTP 연결 종료
# ==========================================

server.quit()

print("\n모든 메일 전송이 완료되었습니다.")
# Out:
# 받는 사람:
# jwaminhye@gmail.com
# jwaminhye@gmail.com
# jwaminhye@gmail.com
# jwaminhye@gmail.com
# jwaminhye@gmail.com
# jwaminhye@gmail.com
# 메일 전송 완료 : jwaminhye@gmail.com
# 메일 전송 완료 : jwaminhye@gmail.com
# 메일 전송 완료 : jwaminhye@gmail.com
# 메일 전송 완료 : jwaminhye@gmail.com
# 메일 전송 완료 : jwaminhye@gmail.com
# 메일 전송 완료 : jwaminhye@gmail.com
#
# 모든 메일 전송이 완료되었습니다.

# %%
# End Of -----------------------------------------------------
